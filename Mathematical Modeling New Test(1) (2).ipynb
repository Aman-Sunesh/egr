# %%
import re
import sys
import io
import numpy as np
import itertools
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import pandas as pd
from copy import deepcopy
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# !pip install nolds
import nolds
# Out:
# Requirement already satisfied: nolds in /home/lab-user/anaconda3/lib/python3.12/site-packages (0.6.1)
# Requirement already satisfied: numpy<3.0,>1.0 in /home/lab-user/anaconda3/lib/python3.12/site-packages (from nolds) (1.26.4)
# Requirement already satisfied: future in /home/lab-user/anaconda3/lib/python3.12/site-packages (from nolds) (1.0.0)
# Requirement already satisfied: setuptools in /home/lab-user/anaconda3/lib/python3.12/site-packages (from nolds) (75.1.0)

# %% [markdown]
# # Synthetic Data Generation

# %%
def Lorentz_System(state, sigma, rho, beta):
    x, y, z = state
    x_dot = sigma*(y-x)
    y_dot = x*(rho-z) - y
    z_dot = x*y - beta*z

    return np.array([x_dot, y_dot, z_dot])

# %% [markdown]
# ### Runga Kutta

# %%
def rk4(state, dt, sigma, rho, beta):
    k1 = Lorentz_System(state, sigma, rho, beta)
    k2 = Lorentz_System(state + 0.5 * dt * k1, sigma, rho, beta)
    k3 = Lorentz_System(state + 0.5 * dt * k2, sigma, rho, beta)
    k4 = Lorentz_System(state + dt * k3, sigma, rho, beta)

    return state + (dt*((k1 + 2*k2 + 2*k3 + k4)/6.0))

# %% [markdown]
# Now, let's visualize the Lorenz attractor using N = 500,000

# %%
dt = 0.01
N = 500000
sigma, rho, beta = 10.0, 28.0, 8.0/3.0
x0, y0, z0 = 1.0, 1.0, 1.0
state = np.array([x0, y0, z0])

trajectory = np.empty((N+1, 3))
trajectory[0] = state

for i in range(1, N+1):
    state = rk4(state, dt, sigma, rho, beta)
    trajectory[i] = state

# %%
# Subsample trajectory to plot fewer points
thin = trajectory[::5]

fig = plt.figure(figsize=(20, 5))

# 3D
ax0 = fig.add_subplot(1, 4, 1, projection='3d')
ax0.plot(thin[:, 0], thin[:, 1], thin[:, 2], lw=0.5)
ax0.set_xlabel('x(t)'); ax0.set_ylabel('y(t)'); ax0.set_zlabel('z(t)')
ax0.set_title('3D View')
ax0.set_box_aspect((1,1,1))  # equal aspect in 3D

# XY
ax1 = fig.add_subplot(1, 4, 2)
ax1.plot(thin[:, 0], thin[:, 1], lw=0.5)
ax1.set_xlabel('x(t)'); ax1.set_ylabel('y(t)')
ax1.set_title('XY Projection')
ax1.set_aspect('equal', 'box')

# YZ
ax2 = fig.add_subplot(1, 4, 3)
ax2.plot(thin[:, 1], thin[:, 2], lw=0.5)
ax2.set_xlabel('y(t)'); ax2.set_ylabel('z(t)')
ax2.set_title('YZ Projection')
ax2.set_aspect('equal', 'box')

# XZ
ax3 = fig.add_subplot(1, 4, 4)
ax3.plot(thin[:, 0], thin[:, 2], lw=0.5)
ax3.set_xlabel('x(t)'); ax3.set_ylabel('z(t)')
ax3.set_title('XZ Projection')
ax3.set_aspect('equal', 'box')

plt.tight_layout()

# %%
plt.plot(trajectory[-1000::5,0], 'o-')

# %%
print("First point of full trajectory:", trajectory[0])
print("Second point of full trajectory:", trajectory[1])
print("Third point of full trajectory:", trajectory[2])
# Out:
# First point of full trajectory: [1. 1. 1.]
# Second point of full trajectory: [1.01256719 1.2599178  0.98489097]
# Third point of full trajectory: [1.04882371 1.52399713 0.97311422]

# %% [markdown]
# # Feed Forward Neural Network

# %%
def make_windows_with_stride(traj, lags, horizon=1):
    """
    traj:    (T, dim) array
    lags:    list of non-negative ints, e.g. [0,5,9]
    horizon: how many steps after max(lags) to predict
    returns:
      X: (N, len(lags)*dim)
      y: (N, dim)
    """
    dim     = traj.shape[1]
    max_lag = max(lags)
    N       = len(traj)
    X, y    = [], []
    for i in range(N - max_lag - horizon):
        # grab the lagged points
        window = [traj[i + lag] for lag in lags]           # list of (dim,)
        X.append(np.concatenate(window))                   # (len(lags)*dim,)
        y.append(traj[i + max_lag + horizon])              # (dim,)
    return np.array(X), np.array(y)

# %% [markdown]
# # Neural Network Class

# %%
class NeuralNetwork:
    def __init__(self, input_size = 64, hidden_size = 30, output_size = 10, learning_rate = 1e-3, epochs = 1000):
        # Hyperparameters
        self.learning_rate = learning_rate
        self.epochs = epochs
        
        # Weights & bias initialization with small random values
        self.W1 = np.random.randn(input_size, hidden_size) * 0.01  
        self.b1 = np.zeros((1, hidden_size))                       
        self.W2 = np.random.randn(hidden_size, output_size) * 0.01 
        self.b2 = np.zeros((1, output_size))                       #

    # ReLU activation function
    def ReLU(self, x):
        return np.maximum(0, x)

    # Derivative of the ReLU function
    def ReLU_deriv(self, x):
        return np.where(x > 0, 1, 0)

    # Linear Activation Function
    def Linear(self, x):
        return x

    def Linear_deriv(self, x):
        return np.ones_like(x)

    # Forward propagation: computes the activations for the hidden and output layers
    def forward_propagation(self, x):
        # Hidden layer
        self.z1 = x @ self.W1 + self.b1
        self.a1 = self.ReLU(self.z1)
    
        # Output layer
        self.z2 = self.a1 @ self.W2 + self.b2
        self.a2 = self.Linear(self.z2)
        
        return self.a2

    # Compute the cost using Mean Squared Error
    def compute_cost(self, y_pred, y_true):
        return np.mean((y_pred - y_true)**2)

    # Back propagation: computes gradients for updating weights and biases
    def back_propagation(self, x, y):       
        m = y.shape[0]
    
        # Compute error at output layer
        error2 = 2 * (self.a2 - y) * self.Linear_deriv(self.z2)

        # Compute gradients for weights and biases for the output layer
        grad_W2 = (self.a1.T @ error2) / m
        grad_b2 = np.sum(error2, axis = 0, keepdims = True) / m

        # Backpropagate the error to the hidden layer
        error1 = (error2 @ self.W2.T) * self.ReLU_deriv(self.z1)

        # Compute gradients for weights and biases for the hidden layer
        grad_W1 = (x.T @ error1) / m
        grad_b1 = np.sum(error1, axis = 0, keepdims = True) / m

        return grad_W1, grad_b1, grad_W2, grad_b2

    # Update the network parameters (weights and biases) using the computed gradients
    def update_parameters(self, grad_W1, grad_b1, grad_W2, grad_b2):
        self.W2 = self.W2 - (self.learning_rate * grad_W2)
        self.b2 = self.b2 - (self.learning_rate * grad_b2)
        self.W1 = self.W1 - (self.learning_rate * grad_W1)
        self.b1 = self.b1 - (self.learning_rate * grad_b1)

    # Train the neural network by iterating over epochs
    def train(self, x, y, optimizer='sgd'):
        optimizer = optimizer.lower()
        
        if optimizer not in ('sgd', 'adam'):
            raise ValueError("Optimizer must be 'sgd' or 'adam'")

        # Adam hyperparameters
        if optimizer == 'adam':
            beta1, beta2 = 0.9, 0.999
            eps = 1e-8
            # Initialize 1st & 2nd moment vectors
            m_W1 = np.zeros_like(self.W1); v_W1 = np.zeros_like(self.W1)
            m_b1 = np.zeros_like(self.b1); v_b1 = np.zeros_like(self.b1)
            m_W2 = np.zeros_like(self.W2); v_W2 = np.zeros_like(self.W2)
            m_b2 = np.zeros_like(self.b2); v_b2 = np.zeros_like(self.b2)

        for epoch in range(1, self.epochs + 1):
            # Perform forward propagation to get outputs
            Y_pred = self.forward_propagation(x)

            # Compute gradients via back propagation
            grad_W1, grad_b1, grad_W2, grad_b2 = self.back_propagation(x, y)

            if optimizer == 'sgd':
                # Update network parameters with the gradients using Standard SGD
                self.update_parameters(grad_W1, grad_b1, grad_W2, grad_b2)

            else:
                # Adam updates
                m_W1 = beta1 * m_W1 + (1 - beta1) * grad_W1
                v_W1 = beta2 * v_W1 + (1 - beta2) * (grad_W1 ** 2)
                m_b1 = beta1 * m_b1 + (1 - beta1) * grad_b1
                v_b1 = beta2 * v_b1 + (1 - beta2) * (grad_b1 ** 2)
                m_W2 = beta1 * m_W2 + (1 - beta1) * grad_W2
                v_W2 = beta2 * v_W2 + (1 - beta2) * (grad_W2 ** 2)
                m_b2 = beta1 * m_b2 + (1 - beta1) * grad_b2
                v_b2 = beta2 * v_b2 + (1 - beta2) * (grad_b2 ** 2)

                # Bias-corrected moments
                mW1_hat = m_W1 / (1 - beta1 ** epoch)
                vW1_hat = v_W1 / (1 - beta2 ** epoch)
                mb1_hat = m_b1 / (1 - beta1 ** epoch)
                vb1_hat = v_b1 / (1 - beta2 ** epoch)
                mW2_hat = m_W2 / (1 - beta1 ** epoch)
                vW2_hat = v_W2 / (1 - beta2 ** epoch)
                mb2_hat = m_b2 / (1 - beta1 ** epoch)
                vb2_hat = v_b2 / (1 - beta2 ** epoch)

                # Update parameters
                self.W1 -= self.learning_rate * mW1_hat / (np.sqrt(vW1_hat) + eps)
                self.b1 -= self.learning_rate * mb1_hat / (np.sqrt(vb1_hat) + eps)
                self.W2 -= self.learning_rate * mW2_hat / (np.sqrt(vW2_hat) + eps)
                self.b2 -= self.learning_rate * mb2_hat / (np.sqrt(vb2_hat) + eps)

            # Every 100 epochs, compute and print the cost for monitoring convergence
            if (epoch%100 == 0):
                cost = self.compute_cost(Y_pred, y)
                print(f"Epoch {epoch}, Cost: {cost:.6f}, Optimizer: {optimizer.upper()}")

    # Predict class labels for input data
    def predict(self, x):
        return self.forward_propagation(x)

# %% [markdown]
# # Training the Neural Network

# %% [markdown]
# ### Splitting into Training, Validation, and Test Set

# %%
n = X.shape[0]
n_train = int(0.70*n)
n_val   = int(0.15*n)

X_train, y_train = X[:n_train], y[:n_train]
X_val,   y_val   = X[n_train:n_train+n_val], y[n_train:n_train+n_val]
X_test,  y_test  = X[n_train+n_val:], y[n_train+n_val:]

# %%
print(f"Total points: {N}")
print(f"  Training : {X_train.shape[0]} samples")
print(f"  Validation: {X_val.shape[0]} samples")
print(f"  Testing  : {X_test.shape[0]} samples")
# Out:
# Total points: 500000
#   Training : 349986 samples
#   Validation: 74997 samples
#   Testing  : 74998 samples

# %% [markdown]
# ### Normalizing the Data Points

# %%
eps = 1e-8   # Added to standard deviation values to avoid division by zero error
Xmu,  Xstd  = X_train.mean(0, keepdims=True), X_train.std(0, keepdims=True) + eps
ymu,  ystd  = y_train.mean(0, keepdims=True), y_train.std(0, keepdims=True) + eps

X_train = (X_train - Xmu)/Xstd
X_val   = (X_val   - Xmu)/Xstd
X_test  = (X_test  - Xmu)/Xstd

y_train = (y_train - ymu)/ystd
y_val   = (y_val   - ymu)/ystd
y_test  = (y_test  - ymu)/ystd

# %%
model = NeuralNetwork(
    input_size    = window_size * 3,
    hidden_size   = 30,
    output_size   = horizon * 3,
    learning_rate = 1e-3,
    epochs        = 1000 
)

model.train(X_train, y_train)
# Out:
# Epoch 100, Cost: 0.984794, Optimizer: SGD
# Epoch 200, Cost: 0.930140, Optimizer: SGD
# Epoch 300, Cost: 0.755238, Optimizer: SGD
# Epoch 400, Cost: 0.489367, Optimizer: SGD
# Epoch 500, Cost: 0.360407, Optimizer: SGD
# Epoch 600, Cost: 0.304687, Optimizer: SGD
# Epoch 700, Cost: 0.250497, Optimizer: SGD
# Epoch 800, Cost: 0.191859, Optimizer: SGD
# Epoch 900, Cost: 0.138167, Optimizer: SGD
# Epoch 1000, Cost: 0.097925, Optimizer: SGD

# %%
y_hat_val = model.predict(X_val)*ystd + ymu
mse_val   = np.mean((y_hat_val - (y_val*ystd + ymu))**2)
print("Validation MSE:", mse_val)
# Out:
# Validation MSE: 7.550538164499468

# %% [markdown]
# Typical x, y, z values on the attractor are roughly in the range [-20, 40]. RMSE = sqrt(MSE) = 2.55. So, on average, each coordinate is off by ≈ 2.5 units one time-step (Δt=0.01) into the future.

# %% [markdown]
# # Hyperparameter Tuning

# %%
# param_grid = {
#     'window_size':  [10, 20, 50],
#     'hidden_size':  [30,  50, 100],
#     'learning_rate':[1e-3,1e-2],
#     'batch_size':   [32,  64],
#     'optimizer':    ['sgd','adam'],
#     'epochs':       [100, 500, 1000]
# }

# best_mse    = float('inf')
# best_params = None
# best_model  = None
# best_hist   = None

# %%
# for combo in itertools.product(*param_grid.values()):
#     params = dict(zip(param_grid.keys(), combo))
#     X_train_w, y_train_w = make_windows(trajectory[:n_train], params['window_size'])
#     X_val_w, y_val_w   = make_windows(trajectory[n_train:n_train+n_val], params['window_size'])

#     model = NeuralNetwork(
#         input_size    = params['window_size'] * 3,
#         hidden_size   = params['hidden_size'],
#         output_size   = 3,                     
#         learning_rate = params['learning_rate'],
#         epochs        = params['epochs']
#     )
    
#     history = model.train(
#         X_train_w, y_train_w,
#         optimizer = params['optimizer'],
#     )

#     val_pred = model.predict(X_val_w)
#     val_mse  = np.mean((val_pred - y_val_w)**2)

#     print(f"Params={params}  →  Val MSE={val_mse:.4e}")
    
#     if val_mse < best_mse:
#         best_mse    = val_mse
#         best_params = params
#         best_model  = deepcopy(model)
#         best_hist   = history

# print("\nBest params:", best_params)
# print("Best validation MSE:", best_mse)

# %%
best_params = {'window_size': 20, 'hidden_size': 100, 'learning_rate': 0.01, 'batch_size': 64, 'optimizer': 'adam', 'epochs': 1000}

# %%
print("\nBest params:", best_params)
# Out:
# Best params: {'window_size': 20, 'hidden_size': 100, 'learning_rate': 0.01, 'batch_size': 64, 'optimizer': 'adam', 'epochs': 1000}

# %%
X_trainval, y_trainval = make_windows(trajectory[:n_train+n_val], lags, 4)
X_test_w,   y_test_w   = make_windows(trajectory[n_train+n_val:], lags, 4)

X_trainval = (X_trainval - Xmu) / Xstd
y_trainval = (y_trainval - ymu) / ystd

X_test_w = (X_test_w - Xmu) / Xstd
y_test_w = (y_test_w - ymu) / ystd

final_model = NeuralNetwork(
    input_size  = best_params['window_size'] * 3,
    hidden_size = best_params['hidden_size'],
    learning_rate = best_params['learning_rate'],
    epochs      = best_params['epochs'],
    output_size = 3
)

final_hist = final_model.train(
    X_trainval, y_trainval,
    optimizer   = best_params['optimizer']    
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 X_trainval, y_trainval = make_windows(trajectory[:n_train+n_val], lags, 4)
#       2 X_test_w,   y_test_w   = make_windows(trajectory[n_train+n_val:], lags, 4)
#       4 X_trainval = (X_trainval - Xmu) / Xstd
#
# Cell In[8], line 7, in make_windows(trajectory, window_size, horizon)
#       4 N = trajectory.shape[0]
#       5 X, y = [], []
# ----> 7 for i in range(N - window_size - horizon + 1):
#       8     X.append((trajectory[i : i + window_size]).flatten())
#       9     y.append((trajectory[i + window_size : i + window_size + horizon]).flatten())
#
# TypeError: unsupported operand type(s) for -: 'int' and 'list'

# %%
test_pred = final_model.predict(X_test_w)
test_mse  = np.mean((test_pred - y_test_w)**2)
print("Test MSE:", test_mse)

# %% [markdown]
# RMSE = 0.074. So, on average, each coorainet is off by ~0.07 units just one time-step (Δt = 0.01) into the future. It captures the immediate local dynamics of a chaotic system with less than a tenth of a unit error

# %%
# # Capture the printed training output into a string buffer
# buffer = io.StringIO()
# old_stdout = sys.stdout
# sys.stdout = buffer

# # Retrain on your best model (this will still print, but now into `buffer`)
# final_model.train(X_trainval, y_trainval, optimizer=best_params['optimizer'])

# sys.stdout = old_stdout

# # Extract epoch & cost from the captured log
# log_lines = buffer.getvalue().splitlines()
# epochs, losses = [], []
# for line in log_lines:
#     m = re.match(r"Epoch\s+(\d+), Cost:\s*([\d\.eE+-]+)", line)
#     if m:
#         epochs.append(int(m.group(1)))
#         losses.append(float(m.group(2)))

# %%
# plt.figure(figsize=(8,4))
# plt.plot(epochs, losses, marker='o', label='Train Loss')
# plt.title("Train Loss (best model retrained)")
# plt.xlabel("Epoch")
# plt.ylabel("MSE")
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
# ---- parameters ----
window_size = best_params['window_size']
n_forecast  = 1000
horizon     = 5
dim         = 3

# 1) Rebuild windows to locate test start
X_all, y_all = make_windows(trajectory, window_size, horizon)
n            = X_all.shape[0]
n_train      = int(0.70 * n)
n_val        = int(0.15 * n)
test_start   = n_train + n_val   # index in X_all where X_test begins

# 2) Grab the window that *ends* right before your test set
#    In trajectory coordinates, that window starts at `test_start` and spans window_size points
L0     = test_start
window = trajectory[L0 : L0 + window_size].copy()   # shape (window_size, 3)

# 3) Closed‐loop forecast
forecast = np.zeros((n_forecast, dim))
for t in range(n_forecast):
    # normalize, predict, denormalize
    x_norm = (window.flatten()[None, :] - Xmu) / Xstd    # shape (1, window_size*3)
    y_norm = final_model.predict(x_norm)                 # shape (1,3)
    y      = (y_norm * ystd + ymu).flatten()
    forecast[t] = y
    # slide the window
    window = np.vstack([window[1:], y])

# 4) Extract the true past & true future in the x‐coordinate
true_past   = trajectory[L0 : L0 + window_size,        0]  # x at t = L0 … L0+window_size–1
true_future = trajectory[L0 + window_size : L0 + window_size + n_forecast, 0]
forecast_x  = forecast[:, 0]

# time axes
t_past = np.arange(-window_size, 0)     # [-window_size … -1]
t_fut  = np.arange(0, n_forecast)       # [0 … n_forecast-1]

# --- Plot 1: true past → true future continuity ---
plt.figure(figsize=(8,4))
plt.plot( t_past, true_past,   'o-', label=f"True past ({window_size})" )
plt.plot(    t_fut, true_future,  '-', label="True future", alpha=0.6 )
plt.axvline(0, color='k', linestyle='--', lw=1)
plt.xlabel("Relative time step")
plt.ylabel("x coordinate")
plt.title("True Lorenz: past → future")
plt.legend()
plt.tight_layout()
plt.show()

# --- Plot 2: model forecast vs true continuation ---
plt.figure(figsize=(8,4))
plt.plot(    t_fut, true_future, label="True future", alpha=0.6 )
plt.plot(    t_fut, forecast_x, '--', label="Forecast",    alpha=0.8 )
plt.xlabel("Relative time step")
plt.ylabel("x coordinate")
plt.title("Closed‐loop Forecast vs. True continuation")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# (1) Build stride windows
lags    = [0, 5, 9]
horizon = 1    # still one-step ahead per predict
dim     = 3

def make_windows_with_stride(traj, lags, horizon=1):
    max_lag = max(lags)
    X, y     = [], []
    N        = len(traj)
    for i in range(N - max_lag - horizon):
        window = [ traj[i+lag] for lag in lags ]
        X.append(np.concatenate(window))    # (len(lags)*dim,)
        y.append(traj[i + max_lag + horizon])
    return np.array(X), np.array(y)

X, y = make_windows_with_stride(trajectory, lags, horizon)

# (2) train/val/test split & normalize exactly as above
#     … same code as in (A) …
n       = len(X)
n_train = int(0.70*n)
n_val   = int(0.15*n)

X_train,   y_train   = X[:n_train],           y[:n_train]
X_val,     y_val     = X[n_train:n_train+n_val],   y[n_train:n_train+n_val]
X_test,    y_test    = X[n_train+n_val:],     y[n_train+n_val:]

eps      = 1e-8
Xmu,  Xstd = X_train.mean(0, keepdims=True), X_train.std(0, keepdims=True) + eps
ymu,  ystd = y_train.mean(0, keepdims=True), y_train.std(0, keepdims=True) + eps

def normalize(a, mu, std): return (a - mu)/std
X_train = normalize(X_train, Xmu, Xstd)
X_val   = normalize(X_val,   Xmu, Xstd)
X_test  = normalize(X_test,  Xmu, Xstd)

y_train = normalize(y_train, ymu, ystd)
y_val   = normalize(y_val,   ymu, ystd)
y_test  = normalize(y_test,  ymu, ystd)



# (3) Instantiate & train your unchanged class
model = NeuralNetwork(
    input_size    = len(lags)*dim,
    hidden_size   = 100,
    output_size   = dim,
    learning_rate = 0.01,
    epochs        = 1000
)

model.train(X_train, y_train, optimizer='adam')

print("\n\n")
test_pred = model.predict(X_test)
test_mse  = np.mean((test_pred - y_test)**2)
print("Test MSE:", test_mse)

# (4) One-step closed-loop forecast with stride
n_forecast = 400
forecast   = np.zeros((n_forecast, dim))

# start from last stride-window in test set
window = X_test[-1].copy()      # still normalized

for t in range(n_forecast):
    y_hat_norm = model.predict(window[None,:])   # (1,3)
    y_hat      = y_hat_norm*ystd + ymu          # de-norm
    forecast[t] = y_hat
    # build next window: drop earliest lag, shift and append the new normed point
    window = np.hstack([
        window[dim:],             # drop the first
        y_hat_norm.ravel()        # append new
    ])


plt.tight_layout()
plt.show()
# Out:
# Epoch 100, Cost: 0.002344, Optimizer: ADAM
# Epoch 200, Cost: 0.000459, Optimizer: ADAM
# Epoch 300, Cost: 0.000149, Optimizer: ADAM
# Epoch 400, Cost: 0.000076, Optimizer: ADAM
# Epoch 500, Cost: 0.000050, Optimizer: ADAM
# Epoch 600, Cost: 0.000038, Optimizer: ADAM
# Epoch 700, Cost: 0.000030, Optimizer: ADAM
# Epoch 800, Cost: 0.000025, Optimizer: ADAM
# Epoch 900, Cost: 0.000022, Optimizer: ADAM
# Epoch 1000, Cost: 0.000019, Optimizer: ADAM
#
#
#
# Test MSE: 1.957210076218836e-05

# %%
len(lags)
# Out:
# 3

# %%
# --- after you’ve trained and built (X_train, X_val, X_test, etc) ---

# 1) Decide where in the trajectory your test‐set windows begin:
n       = len(X)
n_train = int(0.70*n)
n_val   = int(0.15*n)
test_start = n_train + n_val     # index in the *window* array

max_lag = max(lags)              # = 9
horizon = 1                      # your one‐step‐ahead model

# 2) Grab the *first* test window (normalized!) as your seed
window = X_test[0].copy()        # NOT the last one

# 3) Closed‐loop forecast for n_forecast steps
n_forecast = 400
forecast   = np.zeros((n_forecast, dim))

for t in range(n_forecast):
    y_norm     = model.predict(window[None,:])   # (1×3) normalized
    y          = y_norm * ystd + ymu             # denormalize
    forecast[t] = y
    # slide the window: drop the *earliest* lag and append this new normalized point
    window = np.hstack([ window[dim:], y_norm.ravel() ])

# 4) Compute where in the *trajectory* that first forecasted point lives:
#    The window X_test[0] was built from trajectory indices 0:test_start → lagged points,
#    its last lag corresponds to trajectory index = test_start + max_lag - 1.
#    Then the *first* prediction is at +horizon beyond that.
start_idx = test_start + max_lag       # index of the last lag in traj
first_pred_idx = start_idx + horizon   # trajectory index of forecast[0]

# 5) Slice out the true past & true future for plotting
window_size = max_lag + horizon
true_past   = trajectory[first_pred_idx - window_size : first_pred_idx, 0]
true_future = trajectory[first_pred_idx : first_pred_idx + n_forecast, 0]

t_past = np.arange(-window_size, 0)
t_fut  = np.arange(0, n_forecast)

# 6) Plot everything
plt.figure(figsize=(8,4))
plt.plot(t_past,      true_past,    'o-',  label=f"True past ({window_size} steps)")
plt.axvline(0, color='k', linestyle='--', lw=1)
plt.plot(t_fut,       true_future,   '-',  alpha=0.6, label='True future')
plt.plot(t_fut,       forecast[:,0], '--', alpha=0.8, label='Stride‐lag forecast')
plt.xlabel('Relative time step')
plt.ylabel('x coordinate')
plt.title('Stride‐Lag: True past → True future & Forecast')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# --------------------------------------
# 1) Synthetic Lorenz data (Δt=0.01, N=500k)
# --------------------------------------
def Lorenz_System(state, sigma, rho, beta):
    x, y, z = state
    return np.array([
        sigma*(y-x),
        x*(rho-z) - y,
        x*y - beta*z
    ])

def rk4(state, dt, sigma, rho, beta):
    k1 = Lorenz_System(state, sigma, rho, beta)
    k2 = Lorenz_System(state + 0.5*dt*k1, sigma, rho, beta)
    k3 = Lorenz_System(state + 0.5*dt*k2, sigma, rho, beta)
    k4 = Lorenz_System(state + dt*k3,     sigma, rho, beta)
    return state + (dt/6.0)*(k1 + 2*k2 + 2*k3 + k4)

dt = 0.01
N  = 500_000
sigma, rho, beta = 10.0, 28.0, 8.0/3.0

trajectory = np.zeros((N+1, 3))
trajectory[0] = np.array([1.0,1.0,1.0])
for i in range(N):
    trajectory[i+1] = rk4(trajectory[i], dt, sigma, rho, beta)

# --------------------------------------
# 2) Build contiguous windows for multi-step forecasting
# --------------------------------------
window_size = 20
horizon     = 5    # predict 5 steps at once
dim         = 3

def make_windows(traj, window_size, horizon):
    X, y = [], []
    T = len(traj)
    for i in range(T - window_size - horizon + 1):
        X.append(traj[i : i+window_size].flatten())
        y.append(traj[i+window_size : i+window_size+horizon].flatten())
    return np.array(X), np.array(y)

X_all, y_all = make_windows(trajectory, window_size, horizon)

# train/val/test split
n       = len(X_all)
n_train = int(0.70*n)
n_val   = int(0.15*n)

X_train = X_all[:n_train]
y_train = y_all[:n_train]
X_val   = X_all[n_train:n_train+n_val]
y_val   = y_all[n_train:n_train+n_val]
X_test  = X_all[n_train+n_val:]
y_test  = y_all[n_train+n_val:]

# normalize
eps       = 1e-8
Xmu,  Xstd = X_train.mean(0), X_train.std(0) + eps
ymu,  ystd = y_train.mean(0), y_train.std(0) + eps

def norm(a, mu, std): return (a - mu)/std

X_train_n = norm(X_train, Xmu, Xstd)
X_val_n   = norm(X_val,   Xmu, Xstd)
X_test_n  = norm(X_test,  Xmu, Xstd)

y_train_n = norm(y_train, ymu, ystd)
y_val_n   = norm(y_val,   ymu, ystd)
y_test_n  = norm(y_test,  ymu, ystd)

# --------------------------------------
# 3) Your unchanged NeuralNetwork class
# --------------------------------------
class NeuralNetwork:
    def __init__(self, input_size=64, hidden_size=30, output_size=10, learning_rate=1e-3, epochs=1000):
        self.learning_rate = learning_rate
        self.epochs        = epochs
        self.W1 = np.random.randn(input_size,  hidden_size)*0.01
        self.b1 = np.zeros((1, hidden_size))
        self.W2 = np.random.randn(hidden_size, output_size)*0.01
        self.b2 = np.zeros((1, output_size))

    def ReLU(self, x):       return np.maximum(0, x)
    def ReLU_deriv(self, x): return (x>0).astype(float)
    def Linear(self, x):     return x
    def Linear_deriv(self,x):return np.ones_like(x)

    def forward_propagation(self, x):
        self.z1 = x @ self.W1 + self.b1
        self.a1 = self.ReLU(self.z1)
        self.z2 = self.a1 @ self.W2 + self.b2
        self.a2 = self.Linear(self.z2)
        return self.a2

    def compute_cost(self, y_pred, y_true):
        return np.mean((y_pred - y_true)**2)

    def back_propagation(self, x, y):
        m = y.shape[0]
        error2 = 2*(self.a2 - y)*self.Linear_deriv(self.z2)
        grad_W2 = (self.a1.T @ error2)/m
        grad_b2 = error2.sum(0,keepdims=True)/m
        error1  = (error2 @ self.W2.T)*self.ReLU_deriv(self.z1)
        grad_W1 = (x.T @ error1)/m
        grad_b1 = error1.sum(0,keepdims=True)/m
        return grad_W1, grad_b1, grad_W2, grad_b2

    def update_parameters(self, gW1, gb1, gW2, gb2):
        self.W1 -= self.learning_rate * gW1
        self.b1 -= self.learning_rate * gb1
        self.W2 -= self.learning_rate * gW2
        self.b2 -= self.learning_rate * gb2

    def train(self, x, y, optimizer='sgd'):
        optimizer = optimizer.lower()
        if optimizer == 'adam':
            beta1, beta2, eps = 0.9, 0.999, 1e-8
            mW1=vW1=np.zeros_like(self.W1)
            mb1=vb1=np.zeros_like(self.b1)
            mW2=vW2=np.zeros_like(self.W2)
            mb2=vb2=np.zeros_like(self.b2)

        for epoch in range(1, self.epochs+1):
            Y_pred = self.forward_propagation(x)
            gW1, gb1, gW2, gb2 = self.back_propagation(x, y)

            if optimizer=='sgd':
                self.update_parameters(gW1, gb1, gW2, gb2)
            else:  # adam
                # 1st & 2nd moments
                mW1 = beta1*mW1 + (1-beta1)*gW1
                vW1 = beta2*vW1 + (1-beta2)*(gW1**2)
                mb1 = beta1*mb1 + (1-beta1)*gb1
                vb1 = beta2*vb1 + (1-beta2)*(gb1**2)
                mW2 = beta1*mW2 + (1-beta1)*gW2
                vW2 = beta2*vW2 + (1-beta2)*(gW2**2)
                mb2 = beta1*mb2 + (1-beta1)*gb2
                vb2 = beta2*vb2 + (1-beta2)*(gb2**2)
                # bias‐correction
                mW1_hat = mW1/(1-beta1**epoch)
                vW1_hat = vW1/(1-beta2**epoch)
                mb1_hat = mb1/(1-beta1**epoch)
                vb1_hat = vb1/(1-beta2**epoch)
                mW2_hat = mW2/(1-beta1**epoch)
                vW2_hat = vW2/(1-beta2**epoch)
                mb2_hat = mb2/(1-beta1**epoch)
                vb2_hat = vb2/(1-beta2**epoch)
                # update
                self.W1 -= self.learning_rate*mW1_hat/(np.sqrt(vW1_hat)+eps)
                self.b1 -= self.learning_rate*mb1_hat/(np.sqrt(vb1_hat)+eps)
                self.W2 -= self.learning_rate*mW2_hat/(np.sqrt(vW2_hat)+eps)
                self.b2 -= self.learning_rate*mb2_hat/(np.sqrt(vb2_hat)+eps)

            if epoch%100==0:
                cost = self.compute_cost(Y_pred, y)
                print(f"Epoch {epoch}, Cost {cost:.4e}, opt={optimizer.upper()}")

    def predict(self, x):
        return self.forward_propagation(x)

# --------------------------------------
# 4) Train final model on train+val
# --------------------------------------
model = NeuralNetwork(
    input_size    = window_size*dim,
    hidden_size   = 100,
    output_size   = horizon*dim,
    learning_rate = 0.01,
    epochs        = 1000
)
# merge train+val so we have more data:
X_trnv = np.vstack([X_train_n, X_val_n])
y_trnv = np.vstack([y_train_n, y_val_n])
model.train(X_trnv, y_trnv, optimizer='adam')

# --------------------------------------
# 5) Closed-loop, sliding-horizon forecast
# --------------------------------------
n_forecast = 400
forecast   = np.zeros((n_forecast, dim))

# seed with the real window that *ends* at the start of the test split:
test_start = n_train + n_val
L0 = test_start
window_real = trajectory[L0 : L0 + window_size].copy()

t = 0
while t < n_forecast:
    # normalize
    x_norm = ((window_real.flatten()[None,:]) - Xmu) / Xstd
    # predict horizon steps
    y_norm = model.predict(x_norm).flatten()
    y_real = y_norm*ystd + ymu
    y_real = y_real.reshape(horizon, dim)
    # fill as many as we need
    k = min(horizon, n_forecast-t)
    forecast[t:t+k] = y_real[:k]
    # slide real window by k steps
    window_real = np.vstack([ window_real[k:], y_real[:k] ])
    t += k

# --------------------------------------
# 6) Plot true vs forecast (x-coordinate)
# --------------------------------------
# true past:
t_past     = np.arange(-window_size, 0)
true_past  = trajectory[L0 : L0 + window_size, 0]
# true future:
true_future= trajectory[L0 + window_size : L0 + window_size + n_forecast, 0]
t_fut      = np.arange(0, n_forecast)

plt.figure(figsize=(8,4))
plt.plot(t_past,      true_past,   'o-', label=f"True past ({window_size} steps)")
plt.axvline(0, color='k', linestyle='--', lw=1)
plt.plot(t_fut,       true_future, '-',  alpha=0.6, label="True future")
plt.plot(t_fut,       forecast[:,0], '--', alpha=0.8, label="Forecast")
plt.legend()
plt.xlabel("Relative time step")
plt.ylabel("x coordinate")
plt.title("Multi-step (h=5) closed-loop forecast")
plt.tight_layout()
plt.show()
# Out:
# Epoch 100, Cost 1.2984e-03, opt=ADAM
# Epoch 200, Cost 3.1775e-04, opt=ADAM
# Epoch 300, Cost 1.6924e-03, opt=ADAM
# Epoch 400, Cost 1.0697e-04, opt=ADAM
# Epoch 500, Cost 2.4226e-04, opt=ADAM
# Epoch 600, Cost 6.7338e-05, opt=ADAM
# Epoch 700, Cost 6.4280e-05, opt=ADAM
# Epoch 800, Cost 5.5744e-05, opt=ADAM
# Epoch 900, Cost 5.0359e-05, opt=ADAM
# Epoch 1000, Cost 4.9519e-05, opt=ADAM

# %%
horizons = [1,2,3,4,5]
your_rmse = []
for h in horizons:
    err = forecast_x[:h] - true_future[:h]
    your_rmse.append(np.sqrt(np.mean(err**2)))

print("Your Iterative RMSE:", dict(zip(horizons, your_rmse)))
# Out:
# Your Iterative RMSE: {1: 0.5400398676815708, 2: 0.6029805321772845, 3: 0.6641542292636997, 4: 0.7277613983849228, 5: 0.7953174054723984}
